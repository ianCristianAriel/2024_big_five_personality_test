# %% [markdown]
# ```python
# # BSD 2-Clause License
# # Copyright (c) 2024, Ian Cristian Ariel, Yané
# # All rights reserved.
# #
# # This file is part of a project licensed under the BSD 2-Clause License.
# # See the LICENSE file for more information.
# ```

# %% [markdown]
# ## Libraries

# %% [markdown]
# ### Importation

# %%
# data manipulation and analyze
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

# archives manipulation
import requests 
import zipfile  
import os
from dotenv import load_dotenv
from pathlib import Path
from modules.config import *
from modules.extract_data import web_scraping_from_kaggle_api

# data viz
import missingno as msno

# %% [markdown]
# # Data recolection

# %% [markdown]
# ## Web-Scraping from API

# %%
web_scraping_from_kaggle_api()
# Out:
# Dataset ya fue descargado y descomprimido en /Users/cristianariel/Desktop/Progreso/Codigo/Permanentes/cinco_grandes_rasgos_personalidad/data/raw

# %% [markdown]
# ## Load dataset

# %%
# declare path from .csv previous download from web-scraping
csv_path = '../data/raw/IPIP-FFM-data-8Nov2018/data-final.csv'
# load dataset into DataFrame of pandas variable called 'df' 
df = pd.read_csv(csv_path, sep='\t')

# %% [markdown]
# ### Brief data discovery

# %%
df.sample(n=9, random_state=27)
# Out:
#         EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  EXT7  EXT8  EXT9  EXT10  ...  \
# 602283   1.0   4.0   3.0   5.0   2.0   3.0   1.0   5.0   3.0    5.0  ...
# 730803   5.0   1.0   5.0   1.0   5.0   1.0   5.0   2.0   5.0    2.0  ...
# 378842   2.0   3.0   4.0   3.0   4.0   3.0   3.0   3.0   3.0    4.0  ...
# 353367   2.0   2.0   4.0   3.0   3.0   2.0   4.0   3.0   3.0    3.0  ...
# 389083   3.0   2.0   5.0   3.0   3.0   2.0   2.0   4.0   2.0    3.0  ...
# 965627   4.0   1.0   5.0   1.0   5.0   2.0   5.0   3.0   4.0    2.0  ...
# 31737    1.0   3.0   3.0   5.0   1.0   1.0   1.0   5.0   1.0    5.0  ...
# 952841   3.0   3.0   4.0   2.0   4.0   2.0   2.0   3.0   3.0    2.0  ...
# 669886   5.0   1.0   4.0   3.0   4.0   1.0   4.0   3.0   3.0    1.0  ...
#
#                    dateload  screenw  screenh  introelapse  testelapse  \
# 602283  2018-02-07 23:27:57   2560.0   1440.0        109.0       151.0
# 730803  2018-05-04 04:05:52   1366.0    768.0          8.0       142.0
# ...

# %% [markdown]
# ### description and basic statics
# In the next stage (eda) data are analysis visualize

# %%
# describe main statics from DataFrame
df.describe(include='all')
# Out:
#                 EXT1          EXT2          EXT3          EXT4          EXT5  \
# count   1.013558e+06  1.013558e+06  1.013558e+06  1.013558e+06  1.013558e+06
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    2.648067e+00  2.773115e+00  3.288349e+00  3.140595e+00  3.276960e+00
# std     1.264407e+00  1.323943e+00  1.215006e+00  1.237442e+00  1.277593e+00
# min     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%     1.000000e+00  2.000000e+00  2.000000e+00  2.000000e+00  2.000000e+00
# 50%     3.000000e+00  3.000000e+00  3.000000e+00  3.000000e+00  3.000000e+00
# 75%     4.000000e+00  4.000000e+00  4.000000e+00  4.000000e+00  4.000000e+00
# max     5.000000e+00  5.000000e+00  5.000000e+00  5.000000e+00  5.000000e+00
#
# ...

# %% [markdown]
# ### Metadata extraction

# %%
# i identify columns that are not numeric
df.dtypes
# Out:
# EXT1                     float64
# EXT2                     float64
# EXT3                     float64
# EXT4                     float64
# EXT5                     float64
#                           ...
# endelapse                  int64
# IPC                        int64
# country                   object
# lat_appx_lots_of_err      object
# long_appx_lots_of_err     object
# Length: 110, dtype: object

# %%
# i show the unique values from 'country' column
count_unique_values = df.country.unique()
count_unique_values
# Out:
# array(['GB', 'MY', 'KE', 'SE', 'US', 'FI', 'UA', 'PH', 'FR', 'AU', 'IN',
#        'CA', 'NL', 'ZA', 'HK', 'BR', 'CH', 'TH', 'IT', 'ES', 'AE', 'HR',
#        'GR', 'IE', 'OM', 'DE', 'PT', 'SG', 'NONE', 'RO', 'NO', 'BD', 'BN',
#        'NG', 'LT', 'ET', 'ID', 'BE', 'AT', 'DK', 'TZ', 'LU', 'PL', 'JP',
#        'MX', 'CY', 'UG', 'LK', 'TR', 'MM', 'CO', 'EE', 'AR', 'IS', 'HU',
#        'PR', 'PK', 'TN', 'LV', 'CZ', 'NZ', 'RS', 'IL', 'JM', 'CL', 'QA',
#        'SA', 'VN', 'KZ', 'BA', 'MU', 'EG', 'PE', nan, 'SI', 'JO', 'TW',
#        'DO', 'DZ', 'KW', 'MA', 'MT', 'TT', 'BS', 'VE', 'RU', 'KR', 'LR',
#        'GT', 'BG', 'IM', 'GH', 'SO', 'SK', 'MV', 'CN', 'AZ', 'AL', 'KH',
#        'LB', 'UY', 'ZW', 'UZ', 'HN', 'CR', 'GE', 'GI', 'MO', 'NP', 'IR',
#        'MK', 'MN', 'ZM', 'NI', 'BH', 'SD', 'BZ', 'GD', 'KY', 'BB', 'CI',
#        'PG', 'AG', 'VI', 'PY', 'PA', 'SZ', 'SV', 'ME', 'BM', 'AO', 'KG',
#        'FJ', 'VC', 'AF', 'RW', 'GG', 'BY', 'GP', 'AX', 'LY', 'JE', 'MP',
# ...

# %% [markdown]
# ### Data dictionary
# For obtain common info of columns, info about how measured values of each columns or another info of this dataset consult this [codebook.txt](../data/raw/IPIP-FFM-data-8Nov2018/codebook.txt) or this font [kaggle repo](https://www.kaggle.com/datasets/tunguz/big-five-personality-test).
#
# | Columna                   | Tipo de dato | Descripción | Variables únicas  |
# |----------------------------|--------------|-----------|---------------|
# | EXT1                      | float64       | Soy el alma de la fiesta                        | 0, 1, 2, 3, 4, 5                                                          |
# | EXT2                      | float64       | No hablo mucho                                  | 0, 1, 2, 3, 4, 5                                                             |
# | EXT3                      | float64       | Me siento cómodo/a con la gente                | 0, 1, 2, 3, 4, 5                                                         |
# | EXT4                      | float64       | Permanezco en un segundo plano                 | 0, 1, 2, 3, 4, 5                                                        |
# | EXT5                      | float64       | Inicio conversaciones                           | 0, 1, 2, 3, 4, 5                                                          |
# | EXT6                      | float64       | Tengo poco que decir                            | 0, 1, 2, 3, 4, 5                                                           |
# | EXT7                      | float64       | Hablo con muchas personas diferentes en fiestas | 0, 1, 2, 3, 4, 5                                                       |
# | EXT8                      | float64       | No me gusta llamar la atención                 | 0, 1, 2, 3, 4, 5                                                   |
# | EXT9                      | float64       | No me importa ser el centro de atención        | 0, 1, 2, 3, 4, 5                                                      |
# | EXT10                     | float64       | Soy callado/a con los desconocidos             | 0, 1, 2, 3, 4, 5                                                 |
# | EST1                      | float64       | Me estreso fácilmente                          | 0, 1, 2, 3, 4, 5                                                         |
# | EST2                      | float64       | Estoy relajado/a la mayor parte del tiempo     | 0, 1, 2, 3, 4, 5                                                      |
# | EST3                      | float64       | Me preocupo por las cosas                      | 0, 1, 2, 3, 4, 5                                                     |
# | EST4                      | float64       | Rara vez me siento deprimido/a                 | 0, 1, 2, 3, 4, 5                                                   |
# | EST5                      | float64       | Me altero fácilmente                           | 0, 1, 2, 3, 4, 5                                                      |
# | EST6                      | float64       | Me molesto fácilmente                          | 0, 1, 2, 3, 4, 5                                                     |
# | EST7                      | float64       | Cambio de humor con frecuencia                 | 0, 1, 2, 3, 4, 5                                                        |
# | EST8                      | float64       | Tengo cambios de humor frecuentes              | 0, 1, 2, 3, 4, 5                                                   |
# | EST9                      | float64       | Me irrito fácilmente                           | 0, 1, 2, 3, 4, 5                                                      |
# | EST10                     | float64       | A menudo me siento deprimido/a                 | 0, 1, 2, 3, 4, 5                                                  |                                                           |
# | AGR1                      | float64       | Siento poca preocupación por los demás         | 0, 1, 2, 3, 4, 5                                                    |
# | AGR2                      | float64       | Me intereso por las personas                   | 0, 1, 2, 3, 4, 5                                                     |
# | AGR3                      | float64       | Insulto a las personas                         | 0, 1, 2, 3, 4, 5                                                    |
# | AGR4                      | float64       | Simpatizo con los sentimientos de los demás    | 0, 1, 2, 3, 4, 5                                                 |
# | AGR5                      | float64       | No me interesan los problemas de los demás     | 0, 1, 2, 3, 4, 5                                                 |
# | AGR6                      | float64       | Tengo un corazón compasivo                     | 0, 1, 2, 3, 4, 5                                                    |
# | AGR7                      | float64       | No me interesan realmente los demás            | 0, 1, 2, 3, 4, 5                                                     |
# | AGR8                      | float64       | Me tomo tiempo para los demás                  | 0, 1, 2, 3, 4, 5                                                    |
# | AGR9                      | float64       | Siento las emociones de los demás              | 0, 1, 2, 3, 4, 5                                                     |
# | AGR10                     | float64       | Hago que las personas se sientan a gusto       | 0, 1, 2, 3, 4, 5                                                    |                                                      |
# | CSN1                      | float64       | Siempre estoy preparado/a                      | 0, 1, 2, 3, 4, 5                                                    |
# | CSN2                      | float64       | Dejo mis pertenencias por ahí                  | 0, 1, 2, 3, 4, 5                                                   |
# | CSN3                      | float64       | Presto atención a los detalles                 | 0, 1, 2, 3, 4, 5                                                    |
# | CSN4                      | float64       | Hago un desastre de las cosas                  | 0, 1, 2, 3, 4, 5                                                       |
# | CSN5                      | float64       | Hago las tareas de inmediato                   | 0, 1, 2, 3, 4, 5                                                    |
# | CSN6                      | float64       | A menudo olvido devolver las cosas a su lugar  | 0, 1, 2, 3, 4, 5                                                     |
# | CSN7                      | float64       | Me gusta el orden                              | 0, 1, 2, 3, 4, 5                                                          |
# | CSN8                      | float64       | Evado mis responsabilidades                    | 0, 1, 2, 3, 4, 5                                             |
# | CSN9                      | float64       | Sigo un horario                                | 0, 1, 2, 3, 4, 5                                                      |
# | CSN10                     | float64       | Soy meticuloso/a en mi trabajo                 | 0, 1, 2, 3, 4, 5                                                   |
# | OPN1                      | float64       | Tengo un vocabulario rico                      | 0, 1, 2, 3, 4, 5                                                     |
# | OPN2                      | float64       | Tengo dificultad para entender ideas abstractas| 0, 1, 2, 3, 4, 5                                                     |
# | OPN3                      | float64       | Tengo una imaginación vívida                   | 0, 1, 2, 3, 4, 5                                                   |
# | OPN4                      | float64       | No me interesan las ideas abstractas           | 0, 1, 2, 3, 4, 5                                                  |
# | OPN5                      | float64       | Tengo excelentes ideas                         | 0, 1, 2, 3, 4, 5                                                     |
# | OPN6                      | float64       | No tengo buena imaginación                     | 0, 1, 2, 3, 4, 5                                                     |
# | OPN7                      | float64       | Entiendo las cosas rápidamente                 | 0, 1, 2, 3, 4, 5                                                      |
# | OPN8                      | float64       | Uso palabras difíciles                         | 0, 1, 2, 3, 4, 5                                                   |
# | OPN9                      | float64       | Paso tiempo reflexionando sobre las cosas      | 0, 1, 2, 3, 4, 5                                                      |
# | OPN10                     | float64       | Estoy lleno/a de ideas                         | 0, 1, 2, 3, 4, 5                                                          |                                                         |
# | dateload                  | Timestamp    | Marca de tiempo en la que se inició la encuesta| 2016-03-03 02:01:01, ..., 2018-11-08 12:08:45                                                      |
# | screenw                   | float64      | Ancho de la pantalla en píxeles                | 0.0, ..., 13660.0                                                       |
# | screenh                   | float64      | Altura de la pantalla en píxeles               | 0.0, ..., 8802.0                                                        |
# | introelapse               | float64        | Tiempo dedicado a la introducción en segundos  | 0.0, ..., 29443071.0                                                  |
# | testelapse                | float64        | Tiempo dedicado a las preguntas en segundos    |  0.0, ..., 11892718.0                                                    |
# | endelapse                 | int64        | Tiempo dedicado a la finalización en segundos  | 0, ..., 1493327022                                                  |
# | IPC                       | int64      | Registros de IP                                | 1, ..., 725                                                         |
# | country                   | String       | País determinado por información técnica       | 'GB', 'MY', 'KE', ..., 'GN', 'AS', 'SH'                                                                 |
# | lat_appx_lots_of_err      | float64        | Latitud aproximada del usuario                 | -0.0333, ..., NONE                                                        |
# | long_appx_lots_of_err     | float64        | Longitud aproximada del usuario                | -0.0042, ..., NONE                                                       |

# %% [markdown]
# ### Observations to treat into next stage

# %% [markdown]
# 1. float64 to int64 datatype columns: Except for columns refer to latitude, longitude, screen width and screen height, all other columns that declare with 'float64' datatype must be transform to 'int64' datatype format.
# 2. 'dateload' column must be transform to appropriate timestamp format.
# 3. 'IPC' column must be transform to appropriate datatype and format.
